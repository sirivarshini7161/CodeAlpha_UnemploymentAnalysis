# %%
   dir data\processed
# Out:
#   Cell In[20], line 1
#     dir data\processed
#              ^
# SyntaxError: unexpected character after line continuation character

# %%
dir data\processed
# Out:
#   Cell In[19], line 1
#     dir data\processed
#              ^
# SyntaxError: unexpected character after line continuation character

# %%
df1.to_csv("../data/processed/unemployment_cleaned.csv", index=False)
print("Saved cleaned data to data/processed/unemployment_cleaned.csv")
# Out:
# Saved cleaned data to data/processed/unemployment_cleaned.csv

# %%
# Find the row(s) with the highest unemployment rate
df1[df1['Estimated Unemployment Rate (%)'] > 50]
# Out:
#          Region       Date  Estimated Unemployment Rate (%)  \
# 145   Jharkhand 2020-05-31                            55.10
# 242  Puducherry 2020-04-30                            74.51
# 287  Tamil Nadu 2020-04-30                            53.19
# 398       Bihar 2020-04-30                            58.77
# 516   Jharkhand 2020-04-30                            61.48
# 517   Jharkhand 2020-05-31                            70.17
# 613  Puducherry 2020-04-30                            76.74
# 614  Puducherry 2020-05-31                            75.00
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 145           3315038.0                                    37.03  Rural
# 242             49420.0                                    46.79  Rural
# 287           5086200.0                                    33.05  Rural
# 398           1400962.0                                    34.94  Urban
# ...

# %%
# Check for exact duplicate rows
print("Duplicate rows:", df1.duplicated().sum())

# Check for impossible values (rates should be 0-100%, employed count should be positive)
print("\nUnemployment Rate range:", df1['Estimated Unemployment Rate (%)'].min(), "to", df1['Estimated Unemployment Rate (%)'].max())
print("Labour Participation Rate range:", df1['Estimated Labour Participation Rate (%)'].min(), "to", df1['Estimated Labour Participation Rate (%)'].max())
print("Estimated Employed range:", df1['Estimated Employed'].min(), "to", df1['Estimated Employed'].max())

# Check date range per region - does every state have the same number of months recorded?
print("\nRows per region:")
print(df1['Region'].value_counts())
# Out:
# Duplicate rows: 0
#
# Unemployment Rate range: 0.0 to 76.74
# Labour Participation Rate range: 13.33 to 72.57
# Estimated Employed range: 49420.0 to 45777509.0
#
# Rows per region:
# Region
# Andhra Pradesh      28
# Bihar               28
# Chhattisgarh        28
# Delhi               28
# Karnataka           28
# Gujarat             28
# Haryana             28
# Himachal Pradesh    28
# Jharkhand           28
# Maharashtra         28
# Madhya Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Odisha              28
# Rajasthan           28
# Punjab              28
# Telangana           28
# Tamil Nadu          28
# Uttarakhand         27
# Meghalaya           27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
# 1. Drop the 28 fully blank rows
df1 = df1.dropna(subset=['Region'])

# 2. Drop the constant, non-useful Frequency column
df1 = df1.drop(columns=['Frequency'])

# 3. Convert Date from text to a real datetime type
df1['Date'] = pd.to_datetime(df1['Date'], format='%d-%m-%Y')

# 4. Reset the row index (since we dropped rows, the numbering has gaps now)
df1 = df1.reset_index(drop=True)

# Verify everything
print("Shape after cleaning:", df1.shape)
print(df1.dtypes)
df1.head()
# Out:
# Shape after cleaning: (740, 6)
# Region                                             object
# Date                                       datetime64[ns]
# Estimated Unemployment Rate (%)                   float64
# Estimated Employed                                float64
# Estimated Labour Participation Rate (%)           float64
# Area                                               object
# dtype: object
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# ...

# %%
# Drop the fully blank rows first, just for this check (not permanently yet)
temp = df1.dropna(subset=['Region'])

# Convert Date to real datetime, just to check range
temp_dates = pd.to_datetime(temp['Date'], format='%d-%m-%Y')
print("Earliest date:", temp_dates.min())
print("Latest date:", temp_dates.max())
# Out:
# Earliest date: 2019-05-31 00:00:00
# Latest date: 2020-06-30 00:00:00

# %%
for col in df1.select_dtypes(include='object').columns:
    df1[col] = df1[col].str.strip()

for col in df2.select_dtypes(include='object').columns:
    df2[col] = df2[col].str.strip()

print("After stripping:", df1['Frequency'].unique())
# Out:
# After stripping: ['Monthly' nan]

# %%
# Strip whitespace from all text/object columns (not just headers)
for col in df1.select_dtypes(include='object').columns:
    df1[col] = df1[col].str.strip()

for col in df2.select_dtypes(include='object').columns:
    df2[col] = df2[col].str.strip()

# Verify the fix
print(df1['Frequency'].unique())
# Out:
# ['Monthly' nan]

# %%
[' Monthly' nan 'Monthly']
# Out:
#   Cell In[11], line 1
#     [' Monthly' nan 'Monthly']
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(df1['Frequency'].unique())
print(df1['Area'].unique())
print(df1['Region'].unique())
print(df1['Region'].nunique())
# Out:
# [' Monthly' nan 'Monthly']
# ['Rural' nan 'Urban']
# ['Andhra Pradesh' 'Assam' 'Bihar' 'Chhattisgarh' 'Delhi' 'Goa' 'Gujarat'
#  'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand' 'Karnataka'
#  'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Meghalaya' 'Odisha' 'Puducherry'
#  'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana' 'Tripura'
#  'Uttar Pradesh' 'Uttarakhand' 'West Bengal' nan 'Chandigarh']
# 28

# %%
# Strip leading/trailing whitespace from all column names
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

print(df1.columns.tolist())
print(df2.columns.tolist())
# Out:
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Area']
# ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)', 'Estimated Employed', 'Estimated Labour Participation Rate (%)', 'Region.1', 'longitude', 'latitude']

# %%
print(df1['Frequency'].unique())
print(df1['Area'].unique())
print(df1['Region'].unique())
print(df1['Region'].nunique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gsind\OneDrive\Documents\DataScienceProjects\unemployment-analysis-python\venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frequency'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6  Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7  Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8  Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9  Andhra Pradesh   29-02-2020    Monthly                              5.91
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
# Show rows where Region is missing, to inspect them directly
df1[df1['Region'].isnull()]
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 359    NaN   NaN        NaN                               NaN
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
# ...

# %%
print("Missing values per column:")
print(df1.isnull().sum())
print()
print("Total rows:", len(df1))
# Out:
# Missing values per column:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64
#
# Total rows: 768

# %%
print(df1[' Date'].min(), "to", df1[' Date'].max())
df1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df1[' Date'].min(), "to", df1[' Date'].max())
#       2 df1.head()
#
# File c:\Users\gsind\OneDrive\Documents\DataScienceProjects\unemployment-analysis-python\venv\lib\site-packages\pandas\core\series.py:6528, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6520 @doc(make_doc("min", ndim=1))
#    6521 def min(
#    6522     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\gsind\OneDrive\Documents\DataScienceProjects\unemployment-analysis-python\venv\lib\site-packages\pandas\core\generic.py:12453, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12446 def min(
#   12447     self,
#   12448     axis: Axis | None = 0,
#    (...)
#   12451     **kwargs,
#   12452 ):
# ...

# %%
print(df1[' Date'].min(), "to", df1[' Date'].max())
df1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df1[' Date'].min(), "to", df1[' Date'].max())
#       2 df1.head()
#
# File c:\Users\gsind\OneDrive\Documents\DataScienceProjects\unemployment-analysis-python\venv\lib\site-packages\pandas\core\series.py:6528, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6520 @doc(make_doc("min", ndim=1))
#    6521 def min(
#    6522     self,
#    (...)
#    6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\gsind\OneDrive\Documents\DataScienceProjects\unemployment-analysis-python\venv\lib\site-packages\pandas\core\generic.py:12453, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12446 def min(
#   12447     self,
#   12448     axis: Axis | None = 0,
#    (...)
#   12451     **kwargs,
#   12452 ):
# ...

# %%
print("=== File 1: Unemployment in India.csv ===")
print(df1.columns.tolist())
print(df1.dtypes)
print()
print("=== File 2: Unemployment_Rate_upto_11_2020.csv ===")
print(df2.columns.tolist())
print(df2.dtypes)
# Out:
# === File 1: Unemployment in India.csv ===
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object
#
# === File 2: Unemployment_Rate_upto_11_2020.csv ===
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Region.1', 'longitude', 'latitude']
# Region                                       object
#  Date                                        object
#  Frequency                                   object
# ...

# %%
import pandas as pd

df1 = pd.read_csv("../data/raw/Unemployment in India.csv")
df2 = pd.read_csv("../data/raw/Unemployment_Rate_upto_11_2020.csv")

print("File 1 shape:", df1.shape)
print("File 2 shape:", df2.shape)
# Out:
# File 1 shape: (768, 7)
# File 2 shape: (267, 9)
